# %% [markdown]
# ##### lanchain Model - OPENAI

# %% [markdown]
# #### Install dotenv

# %% [markdown]
# ### Load ENV variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os

# %%
os.getenv("OPENAI_API_KEY")
# Out:
# 'your-api-key-here'

# %%
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(model="gpt-4o")

# %% [markdown]
# #### Gemini API key

# %%
 from langchain_google_genai import ChatGoogleGenerativeAI
llm_goo = ChatGoogleGenerativeAI(model="gemini-1.5-pro")

# %%
res = llm.invoke("Who is the CM of Tamil Nadu?")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 res = llm.invoke("Who is the CM of Tamil Nadu?")
#
# File c:\Users\SAI AJAY KUMAR\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\language_models\chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)
#     467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
#     476                 stop=stop,
#     477                 callbacks=config.get("callbacks"),
#     478                 tags=config.get("tags"),
# ...

# %% [markdown]
# ###Static Prompts

# %% [markdown]
# There are three types of prompts
# 1. System
# 2. AI
# 3. User

# %%
prompts = [
    ("system","You are an expert in python"),
    ("user","Write a python function to add two numbers")
]
res1 = llm.invoke(prompts)
print(res1)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[22], line 5
#       1 prompts = [
#       2     ("system","You are an expert in python"),
#       3     ("user","Write a python function to add two numbers")
#       4 ]
# ----> 5 res1 = llm.invoke(prompts)
#       6 print(res1)
#
# File c:\Users\SAI AJAY KUMAR\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\language_models\chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)
#     467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
# ...

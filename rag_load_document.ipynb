# %% [markdown]
# #### Text Loader

# %%
from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader("speech.txt",encoding="utf-8")

# %%
text = loader.load()
len(text)
# print(text[0].page_content)
# Out:
# 1

# %% [markdown]
# #### PDF Loader

# %%
from langchain_community.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader("medical_report.pdf")

# %%
text = loader.load()

# %%
print(text[0].page_content)
# Out:
# Report Status
# Female
# 27 Years:
# :
# :
# :
# Age
# Gender
# Reported
# P
# 9/7/2025   4:56:00PM
# DR NITIN NAHAR
# 474764803
# Ms. NIKITA  CHUDHARY:
# :
# :
# :
# :
# Name
# Lab No.
# Ref By
# Collected
# A/c Status
# 10/7/2025  6:31:50PM
# Final
# Collected at            : Processed at             :BHOPAL CC-82
# Mr Rachel V John Pata So Vitus John Mig 26
# Graund,Indrapuri, Phone: 8770817968
#
# LPL - Bhopal Lab II
# Plot No.05, Mandakini Housing Society, Near
# Apurti Shopping Mall, Kolar Main Road,
# Bhopal, M.P. -  462042
# Test Report
# Test Name Results Units Bio. Ref. Interval
# HEMOGRAM
# (SLS Method, Sheath Flow DC Detection Method, Fluorescent Flow Cytometry, Calculated & Capillary Photometry)
# Hemoglobin  12.00 - 15.00 g/dL13.10
# Packed Cell Volume (PCV)  36.00 - 46.00 %39.50
# RBC Count  3.80 - 4.80 mill/mm34.47
# MCV  83.00 - 101.00 fL88.40
# Mentzer Index   19.8
# MCH  27.00 - 32.00 pg29.30
# MCHC  31.50 - 34.50 g/dL33.20
# ...

# %% [markdown]
# #### CSV Loader

# %%
from langchain_community.document_loaders import CSVLoader

# %%
loader = CSVLoader("employee_records.csv")

# %%
text = loader.load()

# %%
print(text[0].page_content)
# Out:
# Employee_ID: 1
# Employee_Name: Daniel Taylor
# Age: 25
# Country: UK
# Department: HR
# Position: Analyst
# Salary: 142278.32
# Joining_Date: 2023-06-04

# %%
from langchain_community.document_loaders import WebBaseLoader
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
loader = WebBaseLoader("https://www.cricbuzz.com/")

# %%
text = loader.load()

# %%
print(text[0].page_content)
# Out:
# IPL 2026 | Live Cricket Score, Schedule, News, Stats &amp; Videos  | Cricbuzz.comMenuLive ScoresScheduleArchivesNewsSeriesTeamsVideosRankingsMoreMATCHESRR vs SRH - Need 220 to winNZ vs IRE - IRE opt to bowlRCB vs GT - RCB wonSTW vs YSW - Need 49 off 7bWSW vs TBW - Need 23 off 24bALLAllLive NowTodayINTERNATIONALICC Men's T20 World Cup Sub Regional Africa Qualifier Group A 2026Botswana vs Ivory Coast 13th MatchRwanda vs Sierra Leone 14th MatchCameroon vs Kenya 15th MatchNew Zealand tour of Ireland, 2026New Zealand vs Ireland LIVEOnly TestLEAGUEIPL 2026Royal Challengers Bengaluru vs Gujarat Titans Qualifier 1Rajasthan Royals vs Sunrisers Hyderabad LIVEEliminatorT20 Blast 2026Hampshire vs Essex 18th MatchLeicestershire vs Derbyshire 19th MatchWOMENAsian Games Women's T20I Qualifier 2026Malaysia Women vs Thailand Women 3rd Match, Group ANepal Women vs China Women 4th Match, Group BMalaysia Women vs Hong Kong, China Women  5th Match, Group AIndonesia Women vs Nepal Women  6th Match, Group 
# ...

# %% [markdown]
# #### wikipedia Loader

# %%
from langchain_community.document_loaders import WikipediaLoader

# %%
loader = WikipediaLoader("Tell me about GenAI",load_max_docs=1)

# %%
text = loader.load()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\SAI AJAY KUMAR\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_community\utilities\wikipedia.py:39, in WikipediaAPIWrapper.validate_environment(cls, values)
#      38 try:
# ---> 39     import wikipedia
#      41     lang = values.get("lang", "en")
#
# ModuleNotFoundError: No module named 'wikipedia'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 text = loader.load()
#
# File c:\Users\SAI AJAY KUMAR\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\document_loaders\base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
#      38     """Load data into `Document` objects.
#      39
#      40     Returns:
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text = "My dear friends, students, and respected farmers,Today, I want to speak from the heart about three pillars that define the future of our nation:our youth, our education system, and our farmers."

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=50, chunk_overlap=10)

# %%
chunks = splitter.split_text(text)
chunks
# Out:
# ['My dear friends, students, and respected',
#  'respected farmers,Today, I want to speak from the',
#  'from the heart about three pillars that define',
#  'define the future of our nation:our youth, our',
#  'our education system, and our farmers.']

# %% [markdown]
# #### Document Text Loader

# %%
from langchain_community.document_loaders import TextLoader,PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
loader = TextLoader("speech.txt",encoding="utf-8")
texts = loader.load()

# %%
pdfloader = PyPDFLoader("medical_report.pdf")
pdfs = pdfloader.load()

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=50, chunk_overlap=0)
text_chunks = splitter.split_documents(texts)
len(text_chunks)
# Out:
# 44

# %%
text_chunks
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='“My dear friends, students, and respected farmers,'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Today, I want to speak from the heart about three'),
#  Document(metadata={'source': 'speech.txt'}, page_content='pillars that define the future of our nation:'),
#  Document(metadata={'source': 'speech.txt'}, page_content='our youth, our education system, and our farmers.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='🎓 For the Youth'),
#  Document(metadata={'source': 'speech.txt'}, page_content='You are the energy that drives our state forward.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Our commitment is to give you:'),
#  Document(metadata={'source': 'speech.txt'}, page_content='•\tSkill-based education'),
#  Document(metadata={'source': 'speech.txt'}, page_content='•\tDigital learning opportunities'),
# ...

# %%
pdf_chunks= splitter.split_documents(pdfs)
len(pdf_chunks)
# Out:
# 513

# %%
pdf_chunks
# Out:
# [Document(metadata={'producer': 'PDFsharp 6.1.0', 'creator': 'Dr Lal PathLabs Limited', 'creationdate': '2025-07-11T09:10:48+00:00', 'author': 'Dr Lal PathLabs Limited', 'title': 'Patient Report', 'subject': 'Lal Pathlabs Report', 'keywords': 'Dr Lal PathLabs Limited', 'moddate': '2025-07-11T09:10:48+00:00', 'source': 'medical_report.pdf', 'total_pages': 9, 'page': 0, 'page_label': '1'}, page_content='Report Status    \nFemale\n27 Years:\n:\n:\n:\nAge'),
#  Document(metadata={'producer': 'PDFsharp 6.1.0', 'creator': 'Dr Lal PathLabs Limited', 'creationdate': '2025-07-11T09:10:48+00:00', 'author': 'Dr Lal PathLabs Limited', 'title': 'Patient Report', 'subject': 'Lal Pathlabs Report', 'keywords': 'Dr Lal PathLabs Limited', 'moddate': '2025-07-11T09:10:48+00:00', 'source': 'medical_report.pdf', 'total_pages': 9, 'page': 0, 'page_label': '1'}, page_content='Gender\nReported        \nP\n9/7/2025   4:56:00PM'),
# ...

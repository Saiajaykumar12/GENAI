# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="llama-3.3-70b-versatile")

# %%
# question = [{"role":"user","content":"What is the capital of France?"}]
res = llm.invoke("Can you explain me about genAI?")
print(res.content)
# Out:
# GenAI, also known as General Artificial Intelligence or General-Purpose Artificial Intelligence, refers to a type of artificial intelligence that possesses the ability to understand, learn, and apply its knowledge across a wide range of tasks, similar to human intelligence.
#
# The key characteristics of GenAI include:
#
# 1. **Generalizability**: The ability to adapt and apply knowledge to various domains, tasks, and situations.
# 2. **Autonomy**: The capacity to operate independently, making decisions and taking actions without human intervention.
# 3. **Reasoning and Problem-Solving**: The ability to reason, solve problems, and make decisions using logic, intuition, and learning from experience.
# 4. **Knowledge Representation**: The ability to represent and understand knowledge in a way that allows it to be applied to different contexts.
# 5. **Learning and Improvement**: The capacity to learn from experience, adapt to new situations, and improve performance over time.
#
# GenAI is often contrasted with Narrow or Weak AI, which is designed to perform a specific task, such as image recognition, natural language processing, or playing chess. Narrow AI is typically trained on a specific dataset and is not capable of generalizing to other tasks or domains.
#
# The development of GenAI is considered a long-term goal of the AI research community, with potential applications in areas such as:
#
# 1. **Healthcare**: GenAI could help diagnose and treat complex diseases, personalize medicine, and improve patient outcomes.
# 2. **Education**: GenAI could create personalized learning plans, adapt to individual learning styles, and provide real-time feedback.
# 3. **Transportation**: GenAI could optimize traffic flow, improve autonomous vehicles, and enhance public transportation systems.
# 4. **Science and Research**: GenAI could accelerate scientific discoveries, analyze complex data, and identify new patterns and relationships.
#
# However, the development of GenAI also raises important questions and concerns, such as:
#
# 1. **Ethics and Safety**: How can we ensure that GenAI systems are aligned with human values and do not pose a risk to humanity?
# 2. **Transparency and Explainability**: How can we understand and interpret the decisions made by GenAI systems?
# 3. **Job Displacement**: How will GenAI impact the job market and the future of work?
#
# While significant progress has been made in AI research, the development of true GenAI is still an ongoing effort, and many experts believe that it may take several decades or even centuries to achieve.
